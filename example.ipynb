# %% [markdown]
# # MainCode structured notebook
#
# Edit only the values in the first code cell, then run the notebook.
# Nothing is saved to files unless you explicitly turn it on.

# %%
import pandas as pd
from main_code_experiment import MainCodeExperiment

pd.options.display.float_format = "{:.6f}".format

# ============================================================
# CHANGE ONLY THESE VALUES
# ============================================================
MODELS_TO_RUN = ["autodiff", "our_model"]
CONFIGS = [{"NumAllGene": 2, "NumTF": 1, "B": 1}]
DATA_SEEDS = [11, 22]

CHECKPOINTS = [0, 1000, 2000, 3000, 4000, 5000]
INIT_SEED = 0
ENV = 2
T = 100
EPOCHS = 5000

print("MODELS_TO_RUN =", MODELS_TO_RUN)
print("CONFIGS =", CONFIGS)
print("DATA_SEEDS =", DATA_SEEDS)
# Out:
# MODELS_TO_RUN = ['autodiff', 'our_model']
# CONFIGS = [{'NumAllGene': 2, 'NumTF': 1, 'B': 1}]
# DATA_SEEDS = [11, 22]

# %% [markdown]
# ## Create experiment

# %%
demo = MainCodeExperiment(env=ENV, T=T)
print("Device:", demo.device)
# Out:
# Device: cpu

# %% [markdown]
# ## Run models, show plots for each seed, show final table here

# %%
summary_df, details = demo.run(
    configs=CONFIGS,
    data_seeds=DATA_SEEDS,
    models=MODELS_TO_RUN,
    epochs=EPOCHS,
    checkpoints=CHECKPOINTS,
    init_seed=INIT_SEED,
    plot_each_seed=True,
    save_figures=False,
    display_figures=True,
    save_tables=False,
    print_checkpoint_losses=True,
    verbose=False,
    print_every=None,
)

display(summary_df)
# Out:
# ======================================================================
# CONFIG: G=2, TF=1, B=1 | DATA RUN 1/2 | data_seed=11
# ======================================================================
#
# Checkpoint losses (after k epochs):
#   epoch    0 | Autodiff: 4.485416e-01 | OurModel: 4.402293e-01
#   epoch 1000 | Autodiff: 4.656950e-04 | OurModel: 3.985834e-04
#   epoch 2000 | Autodiff: 6.087209e-04 | OurModel: 1.445132e-05
#   epoch 3000 | Autodiff: 3.296478e-04 | OurModel: 8.409036e-04
#   epoch 4000 | Autodiff: 9.991728e-05 | OurModel: 7.857518e-05
#   epoch 5000 | Autodiff: 6.061201e-05 | OurModel: 5.168047e-05
# ======================================================================
# CONFIG: G=2, TF=1, B=1 | DATA RUN 2/2 | data_seed=22
# ======================================================================
#
# Checkpoint losses (after k epochs):
#   epoch    0 | Autodiff: 5.223134e-02 | OurModel: 5.137901e-02
#   epoch 1000 | Autodiff: 2.480046e-04 | OurModel: 6.984727e-05
#   epoch 2000 | Autodiff: 1.959973e-05 | OurModel: 5.199652e-05
#   epoch 3000 | Autodiff: 3.259073e-04 | OurModel: 1.042318e-05
#   epoch 4000 | Autodiff: 1.619359e-04 | OurModel: 3.132174e-05
#   epoch 5000 | Autodiff: 4.907424e-04 | OurModel: 1.672196e-05
# ======================================================================
# FINAL SUMMARY TABLE (all runs) + OVERALL AVG
# ======================================================================
#      Index DataSeed Number of Gene Number of TF B (Trajectory) DataRun  \
# 0        0       11              2            1              1       1
# 1        1       22              2            1              1       2
# 2  AVG_ALL        -              -            -              -       -
#
#   Time points to Calculate Loss in Autodiff  Autodiff Time (s)  Autodiff Loss  \
# 0                                         1           7.558977       0.000061
# 1                                         1           7.496104       0.000491
# 2                                         -           7.527541       0.000276
#
#    OurModel Time (s)  OurModel Loss
# 0           7.832019       0.000052
# 1           7.599043       0.000017
# 2           7.715531       0.000034

# %% [markdown]
# ## Optional: run a single model only

# %%
# Example:
# MODELS_TO_RUN = ["autodiff"]
# or
# MODELS_TO_RUN = ["our_model"]
