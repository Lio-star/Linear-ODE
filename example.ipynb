# %% [markdown]
# # MainCode structured notebook
#
# Edit only the values in the first code cell, then run the notebook.
# Nothing is saved to files unless you explicitly turn it on.

# %%
import pandas as pd
from main_code_experiment import MainCodeExperiment

pd.options.display.float_format = "{:.6f}".format

# ============================================================
# CHANGE ONLY THESE VALUES
# ============================================================
MODELS_TO_RUN = ["autodiff", "our_model", "ou_nll"]
CONFIGS = [{"NumAllGene": 4, "NumTF": 2, "B": 1}]
DATA_SEEDS = [11]

CHECKPOINTS = [0, 1000, 2000, 3000, 4000, 5000]
INIT_SEED = 0
ENV = 2
T = 100
EPOCHS = 5000

print("MODELS_TO_RUN =", MODELS_TO_RUN)
print("CONFIGS =", CONFIGS)
print("DATA_SEEDS =", DATA_SEEDS)
# Out:
# MODELS_TO_RUN = ['autodiff', 'our_model', 'ou_nll']
# CONFIGS = [{'NumAllGene': 4, 'NumTF': 2, 'B': 1}]
# DATA_SEEDS = [11]

# %% [markdown]
# ## Create experiment

# %%
demo = MainCodeExperiment(env=ENV, T=T)
print("Device:", demo.device)
# Out:
# Device: cpu

# %% [markdown]
# ## Run models, show plots for each seed, show final table here

# %%
summary_df, details = demo.run(
    configs=CONFIGS,
    data_seeds=DATA_SEEDS,
    models=MODELS_TO_RUN,
    epochs=EPOCHS,
    checkpoints=CHECKPOINTS,
    init_seed=INIT_SEED,
    plot_each_seed=True,
    save_figures=False,
    display_figures=True,
    save_tables=False,
    print_checkpoint_losses=True,
    verbose=False,
    print_every=None,
)

display(summary_df)
# Out:
# ======================================================================
# CONFIG: G=4, TF=2, B=1 | DATA RUN 1/1 | data_seed=11
# ======================================================================
# Checkpoint losses (after k epochs):
#  epoch    0 | Autodiff: 1.110091e-01 | OurModel: 1.090386e-01 | OU-NLL: -6.080267e-01
#  epoch 1000 | Autodiff: 4.026551e-06 | OurModel: 1.821006e-04 | OU-NLL: -1.609224e+00
#  epoch 2000 | Autodiff: 1.074725e-04 | OurModel: 5.626115e-05 | OU-NLL: -2.113560e+00
#  epoch 3000 | Autodiff: 2.254671e-04 | OurModel: 2.090197e-04 | OU-NLL: -2.552989e+00
#  epoch 4000 | Autodiff: 3.017389e-04 | OurModel: 4.658482e-05 | OU-NLL: -3.070017e+00
#  epoch 5000 | Autodiff: 1.508298e-04 | OurModel: 9.917734e-06 | OU-NLL: -3.558829e+00
# ======================================================================
# FINAL SUMMARY TABLE (all runs) + OVERALL AVG
# ======================================================================
#      Index DataSeed Number of Gene Number of TF B (Trajectory) DataRun  \
# 0        0       11              4            2              1       1
# 1  AVG_ALL        -              -            -              -       -
#
#   Time points to Calculate Loss in Autodiff  Autodiff Time (s)  Autodiff Loss  \
# 0                                         1           7.602022       0.000151
# 1                                         -           7.602022       0.000151
#
#    OurModel Time (s)  OurModel Loss  OU-NLL Time (s)  OU-NLL Loss
# 0           7.799183       0.000010         8.314282    -3.558829
# 1           7.799183       0.000010         8.314282    -3.558829

# %% [markdown]
# ## Optional: run a single model only

# %%
# Example:
# MODELS_TO_RUN = ["autodiff"]
# or
# MODELS_TO_RUN = ["our_model"]
