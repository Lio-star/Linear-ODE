# %% [markdown]
# # MainCode structured notebook
#
# Edit only the values in the first code cell, then run the notebook.
# Nothing is saved to files unless you explicitly turn it on.

# %%
import pandas as pd
from main_code_experiment import MainCodeExperiment

pd.options.display.float_format = "{:.6f}".format

# ============================================================
# CHANGE ONLY THESE VALUES
# ============================================================
MODELS_TO_RUN = ["autodiff", "our_model", "ou_nll"]
CONFIGS = [{"NumAllGene": 100, "NumTF": 80, "B": 1}]
DATA_SEEDS = [11,22,33]

CHECKPOINTS = [0, 1000, 2000, 3000, 4000, 5000]
INIT_SEED = 0
ENV = 2
T = 100
EPOCHS = 5000

print("MODELS_TO_RUN =", MODELS_TO_RUN)
print("CONFIGS =", CONFIGS)
print("DATA_SEEDS =", DATA_SEEDS)
# Out:
# MODELS_TO_RUN = ['autodiff', 'our_model', 'ou_nll']
# CONFIGS = [{'NumAllGene': 100, 'NumTF': 80, 'B': 1}]
# DATA_SEEDS = [11, 22, 33]

# %% [markdown]
# ## Create experiment

# %%
demo = MainCodeExperiment(env=ENV, T=T)
print("Device:", demo.device)
# Out:
# Device: cpu

# %% [markdown]
# ## Run models, show plots for each seed, show final table here

# %%
summary_df, details = demo.run(
    configs=CONFIGS,
    data_seeds=DATA_SEEDS,
    models=MODELS_TO_RUN,
    epochs=EPOCHS,
    checkpoints=CHECKPOINTS,
    init_seed=INIT_SEED,
    plot_each_seed=True,
    save_figures=False,
    display_figures=True,
    save_tables=False,
    print_checkpoint_losses=True,
    verbose=False,
    print_every=None,
)

display(summary_df)
# Out:
# ======================================================================
# CONFIG: G=100, TF=80, B=1 | DATA RUN 1/3 | data_seed=11
# ======================================================================
# Checkpoint losses (after k epochs):
#  epoch    0 | Autodiff: 1.398771e+00 | OurModel: 1.396403e+00 | OU-NLL: 6.669498e-01
#  epoch 1000 | Autodiff: 2.804276e-03 | OurModel: 1.046050e-04 | OU-NLL: -3.399740e-01
#  epoch 2000 | Autodiff: 1.991998e-03 | OurModel: 4.476521e-05 | OU-NLL: -8.496477e-01
#  epoch 3000 | Autodiff: 2.408124e-03 | OurModel: 6.039227e-05 | OU-NLL: -1.350947e+00
#  epoch 4000 | Autodiff: 1.631986e-03 | OurModel: 5.628396e-05 | OU-NLL: -1.850834e+00
#  epoch 5000 | Autodiff: 1.866065e-03 | OurModel: 9.718415e-04 | OU-NLL: -2.318308e+00
# ======================================================================
# CONFIG: G=100, TF=80, B=1 | DATA RUN 2/3 | data_seed=22
# ======================================================================
# Checkpoint losses (after k epochs):
#  epoch    0 | Autodiff: 1.260049e+00 | OurModel: 1.270028e+00 | OU-NLL: 6.195192e-01
#  epoch 1000 | Autodiff: 2.875185e-03 | OurModel: 1.110586e-04 | OU-NLL: -3.863093e-01
#  epoch 2000 | Autodiff: 1.834378e-03 | OurModel: 5.092526e-05 | OU-NLL: -8.957211e-01
#  epoch 3000 | Autodiff: 2.604422e-03 | OurModel: 5.545560e-05 | OU-NLL: -1.396134e+00
#  epoch 4000 | Autodiff: 1.627528e-03 | OurModel: 6.559557e-05 | OU-NLL: -1.895209e+00
#  epoch 5000 | Autodiff: 1.882277e-03 | OurModel: 9.698612e-04 | OU-NLL: -2.369349e+00
# ======================================================================
# CONFIG: G=100, TF=80, B=1 | DATA RUN 3/3 | data_seed=33
# ======================================================================
# Checkpoint losses (after k epochs):
#  epoch    0 | Autodiff: 1.351586e+00 | OurModel: 1.340007e+00 | OU-NLL: 6.463376e-01
#  epoch 1000 | Autodiff: 3.689106e-03 | OurModel: 1.134151e-04 | OU-NLL: -3.590633e-01
#  epoch 2000 | Autodiff: 2.180505e-03 | OurModel: 5.359744e-05 | OU-NLL: -8.689011e-01
#  epoch 3000 | Autodiff: 2.874295e-03 | OurModel: 5.581854e-05 | OU-NLL: -1.368097e+00
#  epoch 4000 | Autodiff: 1.899596e-03 | OurModel: 4.829101e-05 | OU-NLL: -1.868224e+00
#  epoch 5000 | Autodiff: 2.131595e-03 | OurModel: 1.147479e-03 | OU-NLL: -2.343997e+00
# ======================================================================
# FINAL SUMMARY TABLE (all runs) + OVERALL AVG
# ======================================================================
#      Index DataSeed Number of Gene Number of TF B (Trajectory) DataRun  \
# 0        0       11            100           80              1       1
# 1        1       22            100           80              1       2
# 2        2       33            100           80              1       3
# 3  AVG_ALL        -              -            -              -       -
#
#   Time points to Calculate Loss in Autodiff  Autodiff Time (s)  Autodiff Loss  \
# 0                                         1          20.916532       0.001866
# 1                                         1          20.448840       0.001882
# 2                                         1          21.135218       0.002132
# 3                                         -          20.833530       0.001960
#
#    OurModel Time (s)  OurModel Loss  OU-NLL Time (s)  OU-NLL Loss
# 0          17.746168       0.000972        17.916164    -2.318308
# 1          20.781204       0.000970        22.003206    -2.369349
# 2          17.375171       0.001147        19.226166    -2.343997
# 3          18.634181       0.001030        19.715179    -2.343885
